# %% [markdown]
# # Importing Libraries

# %%
# import libraries
import plotly.graph_objs as go
import plotly
from sklearn import metrics
import matplotlib.cm as cm
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
import pandas as pd
import re
import plotly.graph_objects as go
import pandas as pd
import nltk
import textblob
import plotly.express as px
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
import plotly.express as px
import seaborn as sns
from sklearn import svm
plotly.offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Reading the data from the csv file

# %%
#Combining new_dubai_1.csv , new_dubai_2 , new_dubai_3 with the similar table structure using pandas.concat()

df1 = pd.read_csv('new_dubai_1.csv')
df2 = pd.read_csv('new_dubai_2.csv')    
df3 = pd.read_csv('new_dubai_3.csv')
df4 = pd.read_csv('new_d33_1.csv'  )
df5 = pd.read_csv('new_d33_2.csv'  )    
df6 = pd.read_csv('new_d33_3.csv'  )
df7 = pd.read_csv('new_dubai_4.csv')
df8 = pd.read_csv('new_dubai_5.csv')

df = pd.concat([df1, df2, df3 , df4 , df5 , df6 , df7 , df8], ignore_index=True)
df.head()
# Out:
#        user_name      tweet_id   user_location  \
# 0         Drillz  1.640760e+18  Lagos, Nigeria
# 1    Herma Hulda  1.640760e+18             NaN
# 2  𝐌𝐈𝐂𝐇𝐀𝐄𝐋𝐈𝐆𝐄𝐍𝐂𝐄  1.640760e+18             NaN
# 3         Kaliya  1.640760e+18   Bilbao, Spain
# 4       Charehwa  1.640760e+18             NaN
#
#                                   user_description               user_created  \
# 0                                              NaN  2022-10-22 22:53:41+00:00
# 1                                              NaN  2023-02-25 22:30:34+00:00
# 2  Walking ambition, pure pleasure lover, dreamer.  2018-07-21 18:42:42+00:00
# 3                                *****************  2010-03-28 06:10:36+00:00
# 4                                              NaN  2021-11-04 15:50:54+00:00
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             200           910            17676          False
# 1              13            22                0          False
# 2            2788          2802            55854          False
# 3            1139          3807            48604          False
# 4             347           795             5436          False
#
#                         date  \
# 0  2023-03-28 17:10:01+00:00
# 1  2023-03-28 17:09:54+00:00
# 2  2023-03-28 17:09:49+00:00
# 3  2023-03-28 17:09:49+00:00
# 4  2023-03-28 17:09:46+00:00
#
#                                                 text hashtags  \
# 0  RT @jiddarhmorh: Dubai Abaya\nPrice:17,000\nSi...      NaN
# 1  RT @spideycyp_155: Let there be light ~ @Binan...      NaN
# 2  RT @milesautos: Ya Fav Dubai 🔌2019 Lexus RX350...      NaN
# 3  RT @Sydusm: Bolsonaro is hiding in US after fl...      NaN
# 4  RT @ProfJNMoyo: ZED KOUDONARIS smelts gold sto...      NaN
#
#                 source  is_retweet   word
# 0   Twitter for iPhone       False  dubai
# 1      Twitter Web App       False  dubai
# 2  Twitter for Android       False  dubai
# 3   Twitter for iPhone       False  dubai
# 4  Twitter for Android       False  dubai

# %%
df.shape
# Out:
# (11897, 15)

# %% [markdown]
# # Data Preprocessing

# %%
#create a new data frame and store tweet id and user_favorite 
df1 = df[['tweet_id','user_favourites']]
df1.head()
# Out:
#        tweet_id  user_favourites
# 0  1.640760e+18            17676
# 1  1.640760e+18                0
# 2  1.640760e+18            55854
# 3  1.640760e+18            48604
# 4  1.640760e+18             5436

# %%
#drop all zero values in user_favourites column
df1 = df1[df1.user_favourites != 0] 
#drop null values
df1.dropna(inplace=True)
df1.head()
# Out:
#        tweet_id  user_favourites
# 0  1.640760e+18            17676
# 2  1.640760e+18            55854
# 3  1.640760e+18            48604
# 4  1.640760e+18             5436
# 5  1.640760e+18            13601

# %%
# rename column created_at to date
df.rename(columns={'created_at':'Datetime'}, inplace=True)
df.rename(columns={'text':'Text'}, inplace=True)
df.rename(columns={'location': 'User Location'}, inplace=True)
df
# Out:
#                                            user_name      tweet_id  \
# 0                                             Drillz  1.640760e+18
# 1                                        Herma Hulda  1.640760e+18
# 2                                      𝐌𝐈𝐂𝐇𝐀𝐄𝐋𝐈𝐆𝐄𝐍𝐂𝐄  1.640760e+18
# 3                                             Kaliya  1.640760e+18
# 4                                           Charehwa  1.640760e+18
# ...                                              ...           ...
# 11892                                  turkeysamuels  1.637530e+18
# 11893               Eng.Hanan 🤍 / STELLA⭐️/ AQUILA 🦅  1.637530e+18
# 11894                                 TrueToTheRight  1.637530e+18
# 11895                                  Mike Phillips  1.637530e+18
# 11896  🙏🚩सनातनी अंकित कुमार सिंह अदिलपुर अयोध्या🏋️🚩🙏  1.637530e+18
#
#                         user_location  \
# 0                      Lagos, Nigeria
# 1                                 NaN
# 2                                 NaN
# 3                       Bilbao, Spain
# 4                                 NaN
# ...                               ...
# 11892                  Louisiana, USA
# 11893  Found in Saudi out of the blue
# 11894                         IN & CA
# 11895                  United Kingdom
# 11896                  Ayodhya, India
#
#                                         user_description  \
# 0                                                    NaN
# 1                                                    NaN
# 2        Walking ambition, pure pleasure lover, dreamer.
# 3                                      *****************
# 4                                                    NaN
# ...                                                  ...
# 11892  ay man wassup dudes https://t.co/MU4CTxRydK ht...
# 11893  وَلَسَوْفَ يُعْطِيكَ رَبُّكَ فَتَرْضَىٰ. 🦋 Spo...
# 11894  Observant of political affairs of India and th...
# 11895  Former professional rugby player Wales & Briti...
# 11896  🇮🇳तन भी भगवा मन भी भगवा कण-कण भगवा धारी जन्म द...
#
#                     user_created  user_followers  user_friends  \
# 0      2022-10-22 22:53:41+00:00             200           910
# 1      2023-02-25 22:30:34+00:00              13            22
# 2      2018-07-21 18:42:42+00:00            2788          2802
# 3      2010-03-28 06:10:36+00:00            1139          3807
# 4      2021-11-04 15:50:54+00:00             347           795
# ...                          ...             ...           ...
# 11892  2020-03-16 15:38:53+00:00              32           193
# 11893  2010-10-06 07:49:40+00:00             111             0
# 11894  2022-08-29 10:31:29+00:00             123           660
# 11895  2011-11-25 11:55:55+00:00          287263          1173
# 11896  2019-06-05 14:10:41+00:00            1735          1037
#
#        user_favourites  user_verified                       date  \
# 0                17676          False  2023-03-28 17:10:01+00:00
# 1                    0          False  2023-03-28 17:09:54+00:00
# 2                55854          False  2023-03-28 17:09:49+00:00
# 3                48604          False  2023-03-28 17:09:49+00:00
# 4                 5436          False  2023-03-28 17:09:46+00:00
# ...                ...            ...                        ...
# 11892              516          False  2023-03-19 19:11:03+00:00
# 11893              696          False  2023-03-19 19:11:02+00:00
# 11894             6480          False  2023-03-19 19:10:42+00:00
# 11895             4377           True  2023-03-19 19:10:41+00:00
# 11896            31190          False  2023-03-19 19:10:38+00:00
#
#                                                     Text           hashtags  \
# 0      RT @jiddarhmorh: Dubai Abaya\nPrice:17,000\nSi...                NaN
# 1      RT @spideycyp_155: Let there be light ~ @Binan...                NaN
# 2      RT @milesautos: Ya Fav Dubai 🔌2019 Lexus RX350...                NaN
# 3      RT @Sydusm: Bolsonaro is hiding in US after fl...                NaN
# 4      RT @ProfJNMoyo: ZED KOUDONARIS smelts gold sto...                NaN
# ...                                                  ...                ...
# 11892  RT @YourRAGEz: @sneako @upblissed Bro flew to ...                NaN
# 11893  Or pull the cup28 to egypt since egypt are in ...                NaN
# 11894  RT @OSINTWa_com: Taxi driver from Dubai #Amrit...  ['AmritpalSingh']
# 11895  There will only ever be 24 unique platinum ver...                NaN
# 11896  RT @SridharSubbara3: What an evening hearing P...                NaN
#
#                     source  is_retweet   word
# 0       Twitter for iPhone       False  dubai
# 1          Twitter Web App       False  dubai
# 2      Twitter for Android       False  dubai
# 3       Twitter for iPhone       False  dubai
# 4      Twitter for Android       False  dubai
# ...                    ...         ...    ...
# 11892   Twitter for iPhone       False  dubai
# 11893   Twitter for iPhone       False  dubai
# 11894      Twitter Web App       False  dubai
# 11895   Twitter for iPhone       False  dubai
# 11896  Twitter for Android       False  dubai
#
# [11897 rows x 15 columns]

# %%
#convert Datetime column to date only
df['Datetime'] = pd.to_datetime(df['date']).dt.date
df.head()
# Out:
#        user_name      tweet_id   user_location  \
# 0         Drillz  1.640760e+18  Lagos, Nigeria
# 1    Herma Hulda  1.640760e+18             NaN
# 2  𝐌𝐈𝐂𝐇𝐀𝐄𝐋𝐈𝐆𝐄𝐍𝐂𝐄  1.640760e+18             NaN
# 3         Kaliya  1.640760e+18   Bilbao, Spain
# 4       Charehwa  1.640760e+18             NaN
#
#                                   user_description               user_created  \
# 0                                              NaN  2022-10-22 22:53:41+00:00
# 1                                              NaN  2023-02-25 22:30:34+00:00
# 2  Walking ambition, pure pleasure lover, dreamer.  2018-07-21 18:42:42+00:00
# 3                                *****************  2010-03-28 06:10:36+00:00
# 4                                              NaN  2021-11-04 15:50:54+00:00
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             200           910            17676          False
# 1              13            22                0          False
# 2            2788          2802            55854          False
# 3            1139          3807            48604          False
# 4             347           795             5436          False
#
#                         date  \
# 0  2023-03-28 17:10:01+00:00
# 1  2023-03-28 17:09:54+00:00
# 2  2023-03-28 17:09:49+00:00
# 3  2023-03-28 17:09:49+00:00
# 4  2023-03-28 17:09:46+00:00
#
#                                                 Text hashtags  \
# 0  RT @jiddarhmorh: Dubai Abaya\nPrice:17,000\nSi...      NaN
# 1  RT @spideycyp_155: Let there be light ~ @Binan...      NaN
# 2  RT @milesautos: Ya Fav Dubai 🔌2019 Lexus RX350...      NaN
# 3  RT @Sydusm: Bolsonaro is hiding in US after fl...      NaN
# 4  RT @ProfJNMoyo: ZED KOUDONARIS smelts gold sto...      NaN
#
#                 source  is_retweet   word    Datetime
# 0   Twitter for iPhone       False  dubai  2023-03-28
# 1      Twitter Web App       False  dubai  2023-03-28
# 2  Twitter for Android       False  dubai  2023-03-28
# 3   Twitter for iPhone       False  dubai  2023-03-28
# 4  Twitter for Android       False  dubai  2023-03-28

# %%
#clean the text column
def clean_text(text):
    text = re.sub(r'@[A-Za-z0-9]+', '', text)  # Removing @mentions
    text = re.sub(r'#', '', text)  # Removing '#' hash tag
    text = re.sub(r'RT[\s]+', '', text)  # Removing RT
    text = re.sub(r'https?:\/\/\S+', '', text)  # Removing hyperlink
    text = re.sub(r'[^a-zA-Z]', ' ', text)  # Removing punctuation
    text = re.sub(r'\s+', ' ', text)  # Removing extra whitespace
    text = text.lower()  # Converting to lowercase
    return text

# %%
df['Text'] = df['Text'].apply(clean_text)
df['Text'].head()
# Out:
# 0     dubai abaya price sizes available for pickup ...
# 1     let there be light another day another univer...
# 2     ya fav dubai lexus rx seater clean title gcc ...
# 3     bolsonaro is hiding in us after fleeing from ...
# 4     zed koudonaris smelts gold stock in zim sells...
# Name: Text, dtype: object

# %%
df.shape
# Out:
# (11897, 16)

# %% [markdown]
# # Checking if the tweet is ( Positive | Negative or Neutral )

# %%
# classifying tweets as positive, negative and neutral
def get_sentiment(text):
    sentiment = textblob.TextBlob(text).sentiment.polarity
    if sentiment < 0:
        return 'Negative'
    elif sentiment == 0:
        return 'Neutral'
    else:
        return 'Positive'

# %%
df['Sentiment'] = df['Text'].apply(get_sentiment)

# %%
#print the number of positive, negative and neutral tweets
df['Sentiment'].value_counts()
# Out:
# Neutral     5487
# Positive    5016
# Negative    1394
# Name: Sentiment, dtype: int64

# %% [markdown]
# # Using Bag of Word Vactorization-Based Models

# %%
#split the data into train and test
X_train, X_test, y_train, y_test = train_test_split(df['Text'], df['Sentiment'], test_size=0.2, random_state=40)

# %%
#vectorize the data
vectorizer = CountVectorizer()
X_train = vectorizer.fit_transform(X_train)
X_test = vectorizer.transform(X_test)

# %%
# train the model
model = MultinomialNB()
model.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
# predict the model
y_pred = model.predict(X_test)

# %%
# print the accuracy
naive_bayes_accuracy = metrics.accuracy_score(y_test, y_pred)*100
print('Accuracy of Naive Bayes model is: ', naive_bayes_accuracy)
# Out:
# Accuracy of Naive Bayes model is:  86.34453781512606

# %%
# print the confusion matrix
print(metrics.confusion_matrix(y_test, y_pred))
# Out:
# [[225  16  49]
#  [ 36 870 153]
#  [ 25  46 960]]

# %%
# print the classification report
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.79      0.78      0.78       290
#      Neutral       0.93      0.82      0.87      1059
#     Positive       0.83      0.93      0.88      1031
#
#     accuracy                           0.86      2380
#    macro avg       0.85      0.84      0.84      2380
# weighted avg       0.87      0.86      0.86      2380

# %%
# plot the confusion matrix
cm = metrics.confusion_matrix(y_test, y_pred)
plt.figure(figsize=(9, 9))
sns.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square=True, cmap='Blues_r')
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
all_sample_title = 'Accuracy Score: {0}'.format((metrics.accuracy_score(y_test, y_pred))*100)
plt.title(all_sample_title, size=15)
# Out:
# Text(0.5, 1.0, 'Accuracy Score: 86.34453781512606')

# %%
# plot the classification report

cr = metrics.classification_report(y_test, y_pred, output_dict=True)
cr_df = pd.DataFrame(cr).transpose()
cr_df
# Out:
#               precision    recall  f1-score      support
# Negative       0.786713  0.775862  0.781250   290.000000
# Neutral        0.933476  0.821530  0.873933  1059.000000
# Positive       0.826162  0.931135  0.875513  1031.000000
# accuracy       0.863445  0.863445  0.863445     0.863445
# macro avg      0.848784  0.842842  0.843565  2380.000000
# weighted avg   0.869106  0.863445  0.863324  2380.000000

# %% [markdown]
# # Logistic Regression

# %%
# train the model without MultinomialNB
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# c:\Users\usmar\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# LogisticRegression()

# %%
# predict the model
y_pred = model.predict(X_test)

# %%
# print the accuracy
logistic_regression_accuracy = metrics.accuracy_score(y_test, y_pred)*100
print('Accuracy of Logistic Regression model is: ', logistic_regression_accuracy)
# Out:
# Accuracy of Logistic Regression model is:  93.40336134453781

# %%
# print the confusion matrix
print(metrics.confusion_matrix(y_test, y_pred))
# Out:
# [[ 231   42   17]
#  [   9 1027   23]
#  [   6   60  965]]

# %%
# print the classification report
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.94      0.80      0.86       290
#      Neutral       0.91      0.97      0.94      1059
#     Positive       0.96      0.94      0.95      1031
#
#     accuracy                           0.93      2380
#    macro avg       0.94      0.90      0.92      2380
# weighted avg       0.94      0.93      0.93      2380

# %%
# plot the confusion matrix
cm = metrics.confusion_matrix(y_test, y_pred)
plt.figure(figsize=(9, 9))
sns.heatmap(cm, annot=True, fmt=".3f", linewidths=.5,
            square=True, cmap='Blues_r')
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
all_sample_title = 'Accuracy Score: {0}'.format((metrics.accuracy_score(y_test, y_pred))*100)
plt.title(all_sample_title, size=15)
# Out:
# Text(0.5, 1.0, 'Accuracy Score: 93.40336134453781')

# %%
# plot the classification report

cr = metrics.classification_report(y_test, y_pred, output_dict=True)
cr_df = pd.DataFrame(cr).transpose()
cr_df
# Out:
#               precision    recall  f1-score      support
# Negative       0.939024  0.796552  0.861940   290.000000
# Neutral        0.909655  0.969783  0.938757  1059.000000
# Positive       0.960199  0.935984  0.947937  1031.000000
# accuracy       0.934034  0.934034  0.934034     0.934034
# macro avg      0.936293  0.900773  0.916211  2380.000000
# weighted avg   0.935129  0.934034  0.933374  2380.000000

# %% [markdown]
# # Tf-Idf Vectorization-Based Models

# %%
# split data into train and test
X_train, X_test, y_train, y_test = train_test_split(df['Text'], df['Sentiment'], test_size=0.2, random_state=40)

# %%
# vectorize the data
vectorizer = TfidfVectorizer()
X_train = vectorizer.fit_transform(X_train)
X_test = vectorizer.transform(X_test)

# %%
# train the model
model = MultinomialNB()
model.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
# predict the model
y_pred = model.predict(X_test)

# %%
# print the accuracy
naive_bayes_accuracy_tf_idf = metrics.accuracy_score(y_test, y_pred)*100
print('Accuracy of Naive Bayes model with TF-IDF is: ', naive_bayes_accuracy_tf_idf)
# Out:
# Accuracy of Naive Bayes model with TF-IDF is:  84.45378151260505

# %%
# print the confusion matrix
print(metrics.confusion_matrix(y_test, y_pred))
# Out:
# [[133  70  87]
#  [  4 920 135]
#  [  0  74 957]]

# %%
# print the classification report
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.97      0.46      0.62       290
#      Neutral       0.86      0.87      0.87      1059
#     Positive       0.81      0.93      0.87      1031
#
#     accuracy                           0.84      2380
#    macro avg       0.88      0.75      0.79      2380
# weighted avg       0.85      0.84      0.84      2380

# %%
# plot the confusion matrix
cm = metrics.confusion_matrix(y_test, y_pred)
plt.figure(figsize=(9, 9))
sns.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square=True, cmap='Blues_r')
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
all_sample_title = 'Accuracy Score: {0}'.format((metrics.accuracy_score(y_test, y_pred))*100)
plt.title(all_sample_title, size=15)
# Out:
# Text(0.5, 1.0, 'Accuracy Score: 84.45378151260505')

# %%
# plot the classification report

cr = metrics.classification_report(y_test, y_pred, output_dict=True)
cr_df = pd.DataFrame(cr).transpose()
cr_df
# Out:
#               precision    recall  f1-score      support
# Negative       0.970803  0.458621  0.622951   290.000000
# Neutral        0.864662  0.868744  0.866698  1059.000000
# Positive       0.811705  0.928225  0.866063  1031.000000
# accuracy       0.844538  0.844538  0.844538     0.844538
# macro avg      0.882390  0.751863  0.785237  2380.000000
# weighted avg   0.854654  0.844538  0.836723  2380.000000

# %% [markdown]
# # Support Vector Machine

# %%
model = svm.SVC(kernel='linear')
model.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
# predict the model
y_pred = model.predict(X_test)

# %%
# print the accuracy
svm_accuracy = metrics.accuracy_score(y_test, y_pred)*100
print('Accuracy of SVM model is: ', svm_accuracy)
# Out:
# Accuracy of SVM model is:  92.73109243697479

# %%
# print the confusion matrix
print(metrics.confusion_matrix(y_test, y_pred))
# Out:
# [[ 229   33   28]
#  [   7 1016   36]
#  [   6   63  962]]

# %%
# print the classification report
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.95      0.79      0.86       290
#      Neutral       0.91      0.96      0.94      1059
#     Positive       0.94      0.93      0.94      1031
#
#     accuracy                           0.93      2380
#    macro avg       0.93      0.89      0.91      2380
# weighted avg       0.93      0.93      0.93      2380

# %%
# plot the confusion matrix
cm = metrics.confusion_matrix(y_test, y_pred)
plt.figure(figsize=(9, 9))
sns.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square=True, cmap='Blues_r')
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
all_sample_title = 'Accuracy Score: {0}'.format((metrics.accuracy_score(y_test, y_pred))*100)
plt.title(all_sample_title, size=15)
# Out:
# Text(0.5, 1.0, 'Accuracy Score: 92.73109243697479')

# %%
# plot the classification report

cr = metrics.classification_report(y_test, y_pred, output_dict=True)
cr_df = pd.DataFrame(cr).transpose()
cr_df
# Out:
#               precision    recall  f1-score      support
# Negative       0.946281  0.789655  0.860902   290.000000
# Neutral        0.913669  0.959396  0.935974  1059.000000
# Positive       0.937622  0.933075  0.935343  1031.000000
# accuracy       0.927311  0.927311  0.927311     0.927311
# macro avg      0.932524  0.894042  0.910740  2380.000000
# weighted avg   0.928019  0.927311  0.926553  2380.000000

# %% [markdown]
# # Comparing the Models

# %%
# compare the accuracy of the models
models = pd.DataFrame({
    'Model': ['Naive Bayes', 'Logistic Regression', 'Naive Bayes with Tf-Idf', 'SVM'],
    'Score': [naive_bayes_accuracy, logistic_regression_accuracy, naive_bayes_accuracy_tf_idf, svm_accuracy]
})
models.sort_values(by='Score', ascending=False)

# plot the accuracy of the models using plotly
fig = px.bar(models, x='Model', y='Score', color='Score', height=400)
fig.show()
# Out:
# <div>                            <div id="7438b0c5-7e0e-48ac-8485-a34d66b7ee2b" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7438b0c5-7e0e-48ac-8485-a34d66b7ee2b")) {                    Plotly.newPlot(                        "7438b0c5-7e0e-48ac-8485-a34d66b7ee2b",                        [{"alignmentgroup": "True", "hovertemplate": "Model=%{x}<br>Score=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [86.34453781512606, 93.40336134453781, 84.45378151260505, 92.73109243697479], "coloraxis": "coloraxis"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Naive Bayes", "Logistic Regression", "Naive Bayes with Tf-Idf", "SVM"], "xaxis": "x", "y": [86.34453781512606, 93.40336134453781, 84.45378151260505, 92.73109243697479], "yaxis": "y"}],                        {"barmode": "relative", "coloraxis": {"colorbar": {"title": {"text": "Score"}}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}, "height": 400, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d" ...

# %% [markdown]
# # Visualizing the Results

# %%
# visualize the sentiment of the tweets using plotly
fig = px.histogram(df , x="Sentiment", color="Sentiment", barmode="group")
fig.show( )
# Out:
# <div>                            <div id="deba0586-6770-4f84-8ba4-91c92b322411" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("deba0586-6770-4f84-8ba4-91c92b322411")) {                    Plotly.newPlot(                        "deba0586-6770-4f84-8ba4-91c92b322411",                        [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "Sentiment=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "Positive", "marker": {"color": "#636efa"}, "name": "Positive", "offsetgroup": "Positive", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positiv ...

# %%
# visualize the sentiment of the tweets using plotly with facet_col and facet_row and animation_frame
fig = px.histogram(df , x="Sentiment", color="Sentiment", barmode="group", facet_col="Sentiment", facet_row="Sentiment")
fig.show()
# Out:
# <div>                            <div id="33c2abbd-b789-4bf4-8de5-e3d555ec7dc9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("33c2abbd-b789-4bf4-8de5-e3d555ec7dc9")) {                    Plotly.newPlot(                        "33c2abbd-b789-4bf4-8de5-e3d555ec7dc9",                        [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "Sentiment=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "Positive", "marker": {"color": "#636efa"}, "name": "Positive", "offsetgroup": "Positive", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positive", "Positiv ...

# %%
df.head()
# Out:
#        user_name      tweet_id   user_location  \
# 0         Drillz  1.640760e+18  Lagos, Nigeria
# 1    Herma Hulda  1.640760e+18             NaN
# 2  𝐌𝐈𝐂𝐇𝐀𝐄𝐋𝐈𝐆𝐄𝐍𝐂𝐄  1.640760e+18             NaN
# 3         Kaliya  1.640760e+18   Bilbao, Spain
# 4       Charehwa  1.640760e+18             NaN
#
#                                   user_description               user_created  \
# 0                                              NaN  2022-10-22 22:53:41+00:00
# 1                                              NaN  2023-02-25 22:30:34+00:00
# 2  Walking ambition, pure pleasure lover, dreamer.  2018-07-21 18:42:42+00:00
# 3                                *****************  2010-03-28 06:10:36+00:00
# 4                                              NaN  2021-11-04 15:50:54+00:00
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             200           910            17676          False
# 1              13            22                0          False
# 2            2788          2802            55854          False
# 3            1139          3807            48604          False
# 4             347           795             5436          False
#
#                         date  \
# 0  2023-03-28 17:10:01+00:00
# 1  2023-03-28 17:09:54+00:00
# 2  2023-03-28 17:09:49+00:00
# 3  2023-03-28 17:09:49+00:00
# 4  2023-03-28 17:09:46+00:00
#
#                                                 Text hashtags  \
# 0   dubai abaya price sizes available for pickup ...      NaN
# 1   let there be light another day another univer...      NaN
# 2   ya fav dubai lexus rx seater clean title gcc ...      NaN
# 3   bolsonaro is hiding in us after fleeing from ...      NaN
# 4   zed koudonaris smelts gold stock in zim sells...      NaN
#
#                 source  is_retweet   word    Datetime Sentiment
# 0   Twitter for iPhone       False  dubai  2023-03-28  Positive
# 1      Twitter Web App       False  dubai  2023-03-28  Positive
# 2  Twitter for Android       False  dubai  2023-03-28  Positive
# 3   Twitter for iPhone       False  dubai  2023-03-28  Negative
# 4  Twitter for Android       False  dubai  2023-03-28   Neutral

# %%
df.word.unique()
# Out:
# array(['dubai', 'uae', 'd33', 'D33', 'Dubai2023'], dtype=object)

# %%
#dubai and uae replace as 1 and if not dubai and uae replace 0
df['word'] = df['word'].apply(lambda x: 1 if x == 'dubai' or x == 'uae' or x=='Dubai2023' else 0)
df['word'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df.head()
# Out:
#        user_name      tweet_id   user_location  \
# 0         Drillz  1.640760e+18  Lagos, Nigeria
# 1    Herma Hulda  1.640760e+18             NaN
# 2  𝐌𝐈𝐂𝐇𝐀𝐄𝐋𝐈𝐆𝐄𝐍𝐂𝐄  1.640760e+18             NaN
# 3         Kaliya  1.640760e+18   Bilbao, Spain
# 4       Charehwa  1.640760e+18             NaN
#
#                                   user_description               user_created  \
# 0                                              NaN  2022-10-22 22:53:41+00:00
# 1                                              NaN  2023-02-25 22:30:34+00:00
# 2  Walking ambition, pure pleasure lover, dreamer.  2018-07-21 18:42:42+00:00
# 3                                *****************  2010-03-28 06:10:36+00:00
# 4                                              NaN  2021-11-04 15:50:54+00:00
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             200           910            17676          False
# 1              13            22                0          False
# 2            2788          2802            55854          False
# 3            1139          3807            48604          False
# 4             347           795             5436          False
#
#                         date  \
# 0  2023-03-28 17:10:01+00:00
# 1  2023-03-28 17:09:54+00:00
# 2  2023-03-28 17:09:49+00:00
# 3  2023-03-28 17:09:49+00:00
# 4  2023-03-28 17:09:46+00:00
#
#                                                 Text hashtags  \
# 0   dubai abaya price sizes available for pickup ...      NaN
# 1   let there be light another day another univer...      NaN
# 2   ya fav dubai lexus rx seater clean title gcc ...      NaN
# 3   bolsonaro is hiding in us after fleeing from ...      NaN
# 4   zed koudonaris smelts gold stock in zim sells...      NaN
#
#                 source  is_retweet  word    Datetime Sentiment
# 0   Twitter for iPhone       False     1  2023-03-28  Positive
# 1      Twitter Web App       False     1  2023-03-28  Positive
# 2  Twitter for Android       False     1  2023-03-28  Positive
# 3   Twitter for iPhone       False     1  2023-03-28  Negative
# 4  Twitter for Android       False     1  2023-03-28   Neutral

# %%
#count month in Datetime
df['Datetime'].unique()
# Out:
# array([datetime.date(2023, 3, 28), datetime.date(2023, 3, 27),
#        datetime.date(2023, 3, 26), datetime.date(2023, 3, 25),
#        datetime.date(2023, 3, 24), datetime.date(2023, 3, 23),
#        datetime.date(2023, 3, 22), datetime.date(2023, 3, 21),
#        datetime.date(2023, 3, 20), datetime.date(2023, 3, 19)],
#       dtype=object)

# %%
#compare Datetime and word
df.groupby(['Datetime','word']).size().unstack().plot(kind='bar',stacked=True,figsize=(10,5))
# Out:
# <Axes: xlabel='Datetime'>

# %%
#compare Datetime and Sentiment
df.groupby(['Datetime','Sentiment']).size().unstack().plot(kind='bar',stacked=True,figsize=(10,5))
# Out:
# <Axes: xlabel='Datetime'>

# %%
#use plotly to compare Datetime and word
fig = px.histogram(df , x="Datetime", color="word", barmode="group", facet_col="word", facet_row="word")
fig.show()
# Out:
# <div>                            <div id="457b4b20-e39b-4e9c-9898-a9c50cce53da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("457b4b20-e39b-4e9c-9898-a9c50cce53da")) {                    Plotly.newPlot(                        "457b4b20-e39b-4e9c-9898-a9c50cce53da",                        [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "word=1<br>Datetime=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "1", "marker": {"color": "#636efa"}, "name": "1", "offsetgroup": "1", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03 ...

# %%
#use plotly to compare Datetime and Sentiment
fig = px.histogram(df , x="Datetime", color="Sentiment", barmode="group", facet_col="Sentiment", facet_row="Sentiment")
fig.show()
# Out:
# <div>                            <div id="621e035b-bf7b-4a03-9087-a807b394bbca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("621e035b-bf7b-4a03-9087-a807b394bbca")) {                    Plotly.newPlot(                        "621e035b-bf7b-4a03-9087-a807b394bbca",                        [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "Sentiment=Positive<br>Datetime=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "Positive", "marker": {"color": "#636efa"}, "name": "Positive", "offsetgroup": "Positive", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "2023-03-28", "20 ...

# %% [markdown]
# # Word Cloud visualization

# %%
# visualize using wordcloud for negative sentiments
from wordcloud import WordCloud, STOPWORDS
stopwords = set(STOPWORDS)
wordcloud = WordCloud(
    background_color='white',
    stopwords=stopwords,
    max_words=200,
    max_font_size=40,
    scale=3,
    random_state=1
).generate(str(df[df['Sentiment'] == 'Negative']['Text']))
fig = plt.figure(1, figsize=(12, 12))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
# visualize using wordcloud for Positive sentiments
from wordcloud import WordCloud, STOPWORDS
stopwords = set(STOPWORDS)
wordcloud = WordCloud(
    background_color='white',
    stopwords=stopwords,
    max_words=200,
    max_font_size=40,
    scale=3,
    random_state=1
).generate(str(df[df['Sentiment'] == 'Positive']['Text']))
fig = plt.figure(1, figsize=(12, 12))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
# visualize using wordcloud for Neutral sentiments
from wordcloud import WordCloud, STOPWORDS
stopwords = set(STOPWORDS)
wordcloud = WordCloud(
    background_color='white',
    stopwords=stopwords,
    max_words=200,
    max_font_size=40,
    scale=3,
    random_state=1
).generate(str(df[df['Sentiment'] == 'Neutral']['Text']))
fig = plt.figure(1, figsize=(12, 12))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()
